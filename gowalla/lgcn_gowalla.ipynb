# %%
import os
import numpy as np
#os.environ['AUTOGRAPH_VERBOSITY'] = '0'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.0

# %%
dataset_name='gowalla'
dataset_folder='gowalla'
preflix_folder='24_07_30'

# %%
import pickle
import platform

items_num=5855 
users_num=8710 


batch_size=512
epoch_num=1000
hidden_size=64
keep_rate=0.9
layers_num=2


neg_num=4
test_neg_num=1000

# %%
print(items_num)
# Out:
# 5855

# %%
if platform.system().lower() == 'windows':
    print("windows")
    with open('E:/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_train_data_index_from_0.pkl', 'rb') as f:
        train_data=pickle.load(f)
    with open('E:/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_test_data_index_from_0.pkl', 'rb') as f:
        test_data=pickle.load(f)
    with open('E:/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_val_data_index_from_0.pkl', 'rb') as f:
        val_data=pickle.load(f)
elif platform.system().lower() == 'linux':
    print("linux")
    with open('/root/autodl-nas/workspace/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_train_data_index_from_0.pkl', 'rb') as f:
        train_data=pickle.load(f)
    with open('/root/autodl-nas/workspace/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_test_data_index_from_0.pkl', 'rb') as f:
        test_data=pickle.load(f)
    with open('/root/autodl-nas/workspace/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_gcn_val_data_index_from_0.pkl', 'rb') as f:
        val_data=pickle.load(f)
# Out:
# linux

# %%
users_num_max=max(max(train_data['users']),max(test_data['users']),max(val_data['users']))
users_num_min=min(min(train_data['users']),min(test_data['users']),min(val_data['users']))
items_num_max=max(max(train_data['pos_item']),max(test_data['pos_item']),max(val_data['pos_item']))
items_num_min=min(min(train_data['pos_item']),min(test_data['pos_item']),min(val_data['pos_item']))
print('users range:[',users_num_min,',',users_num_max,']')
print('items range:[',items_num_min,',',items_num_max,']')
# Out:
# users range:[ 0 , 8709 ]
# items range:[ 0 , 5854 ]

# %%
print(np.shape(train_data['pos_item']),np.shape(test_data['pos_item']),np.shape(val_data['pos_item']))
# Out:
# (35994,) (9496,) (4729,)

# %%
import scipy.sparse as sp
if platform.system().lower() == 'windows':
    print("windows")
    pre_adj_mat = sp.load_npz('E:/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_s_pre_adj_mat_index_from_0.npz')#D^-1/2*A*D^-1/2
elif platform.system().lower() == 'linux':
    print("linux")
    pre_adj_mat = sp.load_npz('/root/autodl-nas/workspace/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_s_pre_adj_mat_index_from_0.npz')#D^-1/2*A*D^-1/2
    G = sp.load_npz('/root/autodl-nas/workspace/datasets/'+dataset_folder+'/'+dataset_name+'/'+preflix_folder+'/'+dataset_name+'_s_graph_embeddings_mat.npz')#D^-1/2*A*D^-1/2
print('already load adj matrix', pre_adj_mat.shape)
print('graph embeddings', G.shape)
# Out:
# linux
# already load adj matrix (14565, 14565)
# graph embeddings (14565, 128)

# %%
norm_adj=pre_adj_mat#D^-1/2*A*D^-1/2

# %%
class lightgcn_layer(tf.keras.layers.Layer):
    def _convert_sp_mat_to_sp_tensor(self, X):
        """Convert a scipy sparse matrix to tf.SparseTensor.
        Returns:
            tf.SparseTensor: SparseTensor after conversion.
        """
        coo = X.tocoo().astype(np.float32)
        indices = np.mat([coo.row, coo.col]).transpose()
        return tf.SparseTensor(indices, coo.data, coo.shape)
    
    def __init__(self,hidden_size=64, dropout=0., embed_reg=1e-6):
        super(lightgcn_layer, self).__init__()
        self.norm_adj=norm_adj

        initializer = tf.keras.initializers.RandomNormal(mean=0., stddev=0.05,seed=2024)
        
        self.item_embedding_pool = tf.keras.layers.Embedding(items_num,hidden_size,input_length=items_num,
                                                       embeddings_initializer=initializer,
                                                        embeddings_regularizer=tf.keras.regularizers.l2(embed_reg))
        self.user_embedding_pool = tf.keras.layers.Embedding(users_num,hidden_size,input_length=users_num,
                                                       embeddings_initializer=initializer,
                                        embeddings_regularizer=tf.keras.regularizers.l2(embed_reg))

        self.frequence=128

        self.w1_dict={}
        self.w2_dict={}
        for i in range(0, layers_num):
            self.w1_dict[str(i)]=tf.keras.layers.Dense(hidden_size)
            self.w2_dict[str(i)]=tf.keras.layers.Dense(hidden_size)
        self.dropout = tf.keras.layers.Dropout(dropout)
        
        
        self.filters = []
        for l in range(layers_num):
            self.filters.append(
                tf.Variable(
                    tf.random.normal([self.frequence], mean=0.01, stddev=0.001, dtype=tf.float32))
            )

        self.transformers = []
        for l in range(layers_num):
            self.transformers.append(
                tf.Variable(
                    (np.random.normal(0.01, 0.001, (hidden_size, hidden_size)) + np.diag(np.random.normal(0.01, 0.001, hidden_size))).astype(np.float32)
                )
            )
        
    def call(self, inputs,training=False):
        self.item_embedding=self.item_embedding_pool(tf.range(items_num))
        self.user_embedding=self.user_embedding_pool(tf.range(users_num))

        
        A_hat = self._convert_sp_mat_to_sp_tensor(self.norm_adj)
        L_hat = self._convert_sp_mat_to_sp_tensor(self.norm_adj+sp.diags(np.ones(np.shape(self.norm_adj)[0])))
        
        self.G= self._convert_sp_mat_to_sp_tensor(G)
        
        
        
        ego_embeddings = tf.concat(
            [self.user_embedding,self.item_embedding], axis=0
        )
        ori_embeddings=ego_embeddings
        
        self.all_embeddings = [ego_embeddings]

        for k in range(0, layers_num):
            ego_embeddings = tf.matmul(tf.sparse.sparse_dense_matmul(self.G, tf.linalg.diag(self.filters[k])),
                                       tf.sparse.sparse_dense_matmul(self.G, ego_embeddings,
                                                 adjoint_a=True, adjoint_b=False))

            #ego_embeddings = tf.matmul(ego_embeddings, self.transformers[k])
            # User_embedding = tf.nn.relu(tf.matmul(User_embedding, self.transformers[l]))
            self.all_embeddings += [ego_embeddings]
        

        self.all_embeddings = tf.stack(self.all_embeddings, 1)
        self.all_embeddings = tf.reduce_mean(input_tensor=self.all_embeddings, axis=1, keepdims=False)
        
        self.ua_embeddings, self.ia_embeddings = tf.split(
            self.all_embeddings, [users_num,items_num], 0
        )
             
        
        return tf.reshape(self.ua_embeddings,[-1,hidden_size]),tf.reshape(self.ia_embeddings,[-1,hidden_size])

# %%
class lightgcn(tf.keras.models.Model):
    
    def __init__(self):
        super(lightgcn, self).__init__()
        blocks=1
        embed_reg=0.
        layer_norm_eps=1e-6
        num_heads=1
        use_l2norm=False
        
        self.norm_adj=norm_adj

        self.lg_layer=lightgcn_layer(64,0.25,1e-6)
        self.use_l2norm=use_l2norm
        self.temp=0.6
        
    
    def call(self, inputs,training=False,):

       
        self.ua_embeddings, self.ia_embeddings=self.lg_layer(inputs,training)
        if self.use_l2norm:
            self.ua_embeddings = tf.math.l2_normalize(self.ua_embeddings, axis=-1)
            self.ia_embeddings = tf.math.l2_normalize(self.ia_embeddings, axis=-1)
        
        u_g_embeddings = tf.gather(
            params=self.ua_embeddings, indices=tf.reshape(inputs['users'],[1,-1])
        )
        pos_i_g_embeddings = tf.gather(
            params=self.ia_embeddings, indices=tf.reshape(inputs['pos_item'],[1,-1])
        )
        
        neg_indx=tf.random.uniform([tf.shape(inputs['pos_item'])[0],neg_num],dtype=tf.int32,maxval=items_num,minval=0,seed=2023)
        pos_idx = tf.repeat(tf.reshape(inputs['users'],[-1,1]), neg_num, axis=1)

        mask = tf.equal(neg_indx, pos_idx)

        neg_indx = tf.where(mask, tf.random.uniform([tf.shape(inputs['pos_item'])[0],neg_num],dtype=tf.int32,maxval=items_num,minval=0,seed=2024), neg_indx)
        
        
        neg_i_g_embeddings = tf.gather(
            params=self.ia_embeddings, indices=tf.reshape(neg_indx,[tf.shape(neg_indx)[1],-1])
        )

        pos_score = tf.transpose(tf.reduce_sum(tf.multiply(u_g_embeddings, pos_i_g_embeddings), axis=-1),[1,0])  # (None, 1)
        
        if full==True:
            
            #E=tf.concat([self.ua_embeddings, self.ia_embeddings], axis=0)
            #tf.print(self.lg_layer.item_embedding)
            #grad_E = tf.sparse.sparse_dense_matmul(self.lg_layer.norm_lap_adj, E)
            #self.dirichlet_energy = 0.5 * tf.reduce_sum(tf.norm(grad_E, axis=1)**2)
            #tf.print(self.dirichlet_energy)
            
            neg_i_g_embeddings=tf.expand_dims(self.ia_embeddings,1)
            neg_score = tf.transpose(tf.reduce_sum(tf.multiply(u_g_embeddings, neg_i_g_embeddings), axis=-1),[1,0])
            
            indices = tf.tile(tf.reshape(tf.range(items_num), [1, items_num]),[tf.shape(inputs['pos_item'])[0],1])
            #tf.print(tf.shape(indices))
            pos_idx_expanded = tf.tile(tf.reshape(inputs['pos_item'],[-1,1]), (1, items_num))
            #tf.print(tf.shape(pos_idx_expanded))
            test_mask = tf.math.not_equal(indices, pos_idx_expanded)#[b,1430]
            #tf.print(test_mask[0])
            #neg_score=tf.where(test_mask,neg_score,-1e10)
            neg_score=tf.where(neg_score == 0,-1e10,neg_score)
        else:
            neg_score = tf.transpose(tf.reduce_sum(tf.multiply(u_g_embeddings, neg_i_g_embeddings), axis=-1),[1,0])

        logits = tf.nn.softmax(tf.concat([pos_score, neg_score], axis=-1))
        
        loss = tf.reduce_mean(- tf.math.log(tf.math.sigmoid(pos_score-neg_score)))

        
        self.add_loss(loss)
        
        return logits
    
    def summary(self):
        inputs = {
            'users': tf.keras.layers.Input(shape=(), dtype=tf.int32),
            'pos_item': tf.keras.layers.Input(shape=(), dtype=tf.int32)
        }
        tf.keras.models.Model(inputs=inputs, outputs=self.call(inputs)).summary()

# %%
def hr(rank, k):
    """Hit Rate.
    Args:
        :param rank: A list.
        :param k: A scalar(int).
    :return: hit rate.
    """
    res = 0.0
    for r in rank:
        if r < k:
            res += 1
    return res / len(rank)


def mrr(rank, k):
    """Mean Reciprocal Rank.
    Args:
        :param rank: A list.
        :param k: A scalar(int).
    :return: mrr.
    """
    mrr = 0.0
    for r in rank:
        if r < k:
            mrr += 1 / (r + 1)
    return mrr / len(rank)


def ndcg(rank, k):
    """Normalized Discounted Cumulative Gain.
    Args:
        :param rank: A list.
        :param k: A scalar(int).
    :return: ndcg.
    """
    res = 0.0
    for r in rank:
        if r < k:
            res += 1 / np.log2(r + 2)
    return res / len(rank)


def eval_rank(pred_y, metric_names, k=10):
    """Evaluate
        Args:
            :param pred_y: A ndarray.
            :param metric_names: A list like ['hr'].
            :param k: A scalar(int).
        :return: A result dict such as {'hr':, 'ndcg':, ...}
    """
    rank = pred_y.argsort().argsort()[:, 0]
    res_dict = {}
    for name in metric_names:
        if name == 'hr':
            res = hr(rank, k)
        elif name == 'ndcg':
            res = ndcg(rank, k)
        elif name == 'mrr':
            res = mrr(rank, k)
        elif name == 'precision':
            res = hr(rank, 1)
        else:
            break
        res_dict[name] = res
    return res_dict


def eval_pos_neg(model, test_data, metric_names, k=10, batch_size=None):
    """Evaluate the performance of Top-k recommendation algorithm.
    Note: Test data must contain some negative samples(>= k) and one positive samples.
    Args:
        :param model: A model built-by tensorflow.
        :param test_data: A dict.
        :param metric_names: A list like ['hr'].
        :param k: A scalar(int).
        :param batch_size: A scalar(int).
    :return: A result dict such as {'hr':, 'ndcg':, ...}
    """
    
    if len(test_data['users'])<30000:
        pred_y = - model.predict(test_data, batch_size)
        print(np.shape(pred_y))
        return eval_rank(pred_y, metric_names, k)
    else:
        final_dict={}
        for i in metric_names:
            final_dict.update({i:[]})
        for i in range(0,int(len(test_data['users'])/30000)+1):
            part_test_data_users=test_data['users'][i*30000:(i+1)*30000]
            part_test_data_poss=test_data['pos_item'][i*30000:(i+1)*30000]
            part_test_data = {'users': np.array(part_test_data_users), 'pos_item': np.array(part_test_data_poss)}
            pred_y = - model.predict(part_test_data, batch_size)
            print(np.shape(pred_y))
            part_dict=eval_rank(pred_y, metric_names, k)
            for i in metric_names:
                final_dict [i].append(part_dict[i])
        for i in metric_names:
            final_dict [i]=np.mean(final_dict [i])
        return final_dict

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
from time import time
from tensorflow.keras.backend import clear_session
number=1
max_layers=10
ave_dict={'hr':[],'mrr':[],'ndcg':[],'precision':[]}
t1 = time()
strategy = tf.distribute.MirroredStrategy()
batch_size=batch_size*strategy.num_replicas_in_sync
for i in range(number):
    clear_session()
    with strategy.scope():
        pred=0
        full=False
        model = lightgcn()
        #model.summary()
        optimizer=tf.keras.optimizers.Nadam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004)
        #optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
        model.compile(optimizer=optimizer)
        model.fit(
                x=train_data,
                epochs=epoch_num,
                verbose=1,
                batch_size=batch_size,
            callbacks=callback,
            validation_data=val_data)
        '''model.fit(
                x=train_data,
                epochs=epoch_num,
                verbose=0,
                batch_size=batch_size,
            validation_data=val_data)'''
        
    pred=1
    full=True
    eval_dict = eval_pos_neg(model, test_data, ['hr', 'mrr', 'ndcg','precision'], 10, batch_size)
    #tf.print(model.dirichlet_energy)
    #eval_dict = eval_pos_neg_full(model, test_data, ['hr', 'mrr', 'ndcg','precision'], 10, batch_size)
    for m in ['hr', 'mrr', 'ndcg','precision']:
        ave_dict[m].append(eval_dict[m])
    print('Precision = %.4f, HR = %.4f, MRR = %.4f, NDCG = %.4f'
              % (eval_dict['precision'], eval_dict['hr'], eval_dict['mrr'], eval_dict['ndcg']))
t2 = time()
print('Fit [%.1f s]: Precision = %.4f, HR = %.4f, MRR = %.4f, NDCG = %.4f'
              % (t2 - t1, np.mean(ave_dict['precision']),np.mean(ave_dict['hr']), np.mean(ave_dict['mrr']), np.mean(ave_dict['ndcg'])))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/1000
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 69/71 [============================>.] - ETA: 0s - loss: 0.6954INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 71/71 [==============================] - 12s 62ms/step - loss: 0.6954 - val_loss: 0.6953
# Epoch 2/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6953 - val_loss: 0.6953
# Epoch 3/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6951 - val_loss: 0.6953
# Epoch 4/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6950 - val_loss: 0.6952
# Epoch 5/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6949 - val_loss: 0.6952
# Epoch 6/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6948 - val_loss: 0.6951
# Epoch 7/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6946 - val_loss: 0.6951
# Epoch 8/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6945 - val_loss: 0.6950
# Epoch 9/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6944 - val_loss: 0.6950
# Epoch 10/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6943 - val_loss: 0.6950
# Epoch 11/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6942 - val_loss: 0.6950
# Epoch 12/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6941 - val_loss: 0.6949
# Epoch 13/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6940 - val_loss: 0.6949
# Epoch 14/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6939 - val_loss: 0.6949
# Epoch 15/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6938 - val_loss: 0.6949
# Epoch 16/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6937 - val_loss: 0.6948
# Epoch 17/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6936 - val_loss: 0.6948
# Epoch 18/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6935 - val_loss: 0.6948
# Epoch 19/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6934 - val_loss: 0.6948
# Epoch 20/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6934 - val_loss: 0.6948
# Epoch 21/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6933 - val_loss: 0.6947
# Epoch 22/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6932 - val_loss: 0.6947
# Epoch 23/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6931 - val_loss: 0.6947
# Epoch 24/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6930 - val_loss: 0.6947
# Epoch 25/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6929 - val_loss: 0.6947
# Epoch 26/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6928 - val_loss: 0.6947
# Epoch 27/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6927 - val_loss: 0.6947
# Epoch 28/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6926 - val_loss: 0.6947
# Epoch 29/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6925 - val_loss: 0.6947
# Epoch 30/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6924 - val_loss: 0.6946
# Epoch 31/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6923 - val_loss: 0.6946
# Epoch 32/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6922 - val_loss: 0.6946
# Epoch 33/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6921 - val_loss: 0.6946
# Epoch 34/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6920 - val_loss: 0.6946
# Epoch 35/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6919 - val_loss: 0.6946
# Epoch 36/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6918 - val_loss: 0.6946
# Epoch 37/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6917 - val_loss: 0.6946
# Epoch 38/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6916 - val_loss: 0.6946
# Epoch 39/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6915 - val_loss: 0.6946
# Epoch 40/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6914 - val_loss: 0.6946
# Epoch 41/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6912 - val_loss: 0.6946
# Epoch 42/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6911 - val_loss: 0.6946
# Epoch 43/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6910 - val_loss: 0.6945
# Epoch 44/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6908 - val_loss: 0.6945
# Epoch 45/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6907 - val_loss: 0.6945
# Epoch 46/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6906 - val_loss: 0.6945
# Epoch 47/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6904 - val_loss: 0.6945
# Epoch 48/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6902 - val_loss: 0.6945
# Epoch 49/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6901 - val_loss: 0.6945
# Epoch 50/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6899 - val_loss: 0.6944
# Epoch 51/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6898 - val_loss: 0.6944
# Epoch 52/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6896 - val_loss: 0.6944
# Epoch 53/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6894 - val_loss: 0.6944
# Epoch 54/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6892 - val_loss: 0.6943
# Epoch 55/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6890 - val_loss: 0.6943
# Epoch 56/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6888 - val_loss: 0.6943
# Epoch 57/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6886 - val_loss: 0.6943
# Epoch 58/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6884 - val_loss: 0.6942
# Epoch 59/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6882 - val_loss: 0.6942
# Epoch 60/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6880 - val_loss: 0.6941
# Epoch 61/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6878 - val_loss: 0.6941
# Epoch 62/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6875 - val_loss: 0.6941
# Epoch 63/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6873 - val_loss: 0.6940
# Epoch 64/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6870 - val_loss: 0.6939
# Epoch 65/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6868 - val_loss: 0.6939
# Epoch 66/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6865 - val_loss: 0.6939
# Epoch 67/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6863 - val_loss: 0.6938
# Epoch 68/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6860 - val_loss: 0.6937
# Epoch 69/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6857 - val_loss: 0.6936
# Epoch 70/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6854 - val_loss: 0.6936
# Epoch 71/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6851 - val_loss: 0.6935
# Epoch 72/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6848 - val_loss: 0.6934
# Epoch 73/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6845 - val_loss: 0.6933
# Epoch 74/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6841 - val_loss: 0.6933
# Epoch 75/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6838 - val_loss: 0.6932
# Epoch 76/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6835 - val_loss: 0.6931
# Epoch 77/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6831 - val_loss: 0.6930
# Epoch 78/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6828 - val_loss: 0.6929
# Epoch 79/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6824 - val_loss: 0.6928
# Epoch 80/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6820 - val_loss: 0.6926
# Epoch 81/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6817 - val_loss: 0.6926
# Epoch 82/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6813 - val_loss: 0.6924
# Epoch 83/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6809 - val_loss: 0.6923
# Epoch 84/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6805 - val_loss: 0.6922
# Epoch 85/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6801 - val_loss: 0.6921
# Epoch 86/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6797 - val_loss: 0.6919
# Epoch 87/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6793 - val_loss: 0.6918
# Epoch 88/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6788 - val_loss: 0.6916
# Epoch 89/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6784 - val_loss: 0.6915
# Epoch 90/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6779 - val_loss: 0.6913
# Epoch 91/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6775 - val_loss: 0.6912
# Epoch 92/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6770 - val_loss: 0.6909
# Epoch 93/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6765 - val_loss: 0.6908
# Epoch 94/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6760 - val_loss: 0.6906
# Epoch 95/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6755 - val_loss: 0.6905
# Epoch 96/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6751 - val_loss: 0.6903
# Epoch 97/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6746 - val_loss: 0.6900
# Epoch 98/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6740 - val_loss: 0.6898
# Epoch 99/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6735 - val_loss: 0.6896
# Epoch 100/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6730 - val_loss: 0.6895
# Epoch 101/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6724 - val_loss: 0.6892
# Epoch 102/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6719 - val_loss: 0.6890
# Epoch 103/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6713 - val_loss: 0.6887
# Epoch 104/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6708 - val_loss: 0.6886
# Epoch 105/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6702 - val_loss: 0.6883
# Epoch 106/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6696 - val_loss: 0.6882
# Epoch 107/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6690 - val_loss: 0.6879
# Epoch 108/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6684 - val_loss: 0.6876
# Epoch 109/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6678 - val_loss: 0.6873
# Epoch 110/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6672 - val_loss: 0.6871
# Epoch 111/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6666 - val_loss: 0.6868
# Epoch 112/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6660 - val_loss: 0.6865
# Epoch 113/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6653 - val_loss: 0.6864
# Epoch 114/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6647 - val_loss: 0.6860
# Epoch 115/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6640 - val_loss: 0.6858
# Epoch 116/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6634 - val_loss: 0.6854
# Epoch 117/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6627 - val_loss: 0.6851
# Epoch 118/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6621 - val_loss: 0.6847
# Epoch 119/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6614 - val_loss: 0.6845
# Epoch 120/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6607 - val_loss: 0.6843
# Epoch 121/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6600 - val_loss: 0.6839
# Epoch 122/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6593 - val_loss: 0.6836
# Epoch 123/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6587 - val_loss: 0.6832
# Epoch 124/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6579 - val_loss: 0.6829
# Epoch 125/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6572 - val_loss: 0.6825
# Epoch 126/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6564 - val_loss: 0.6821
# Epoch 127/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6557 - val_loss: 0.6819
# Epoch 128/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6550 - val_loss: 0.6814
# Epoch 129/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6542 - val_loss: 0.6811
# Epoch 130/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6534 - val_loss: 0.6810
# Epoch 131/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6526 - val_loss: 0.6804
# Epoch 132/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6519 - val_loss: 0.6800
# Epoch 133/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6512 - val_loss: 0.6797
# Epoch 134/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 0.6504 - val_loss: 0.6794
# Epoch 135/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 0.6496 - val_loss: 0.6788
# Epoch 136/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6487 - val_loss: 0.6786
# Epoch 137/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6480 - val_loss: 0.6782
# Epoch 138/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6473 - val_loss: 0.6777
# Epoch 139/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6463 - val_loss: 0.6772
# Epoch 140/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6455 - val_loss: 0.6769
# Epoch 141/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6446 - val_loss: 0.6765
# Epoch 142/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6438 - val_loss: 0.6760
# Epoch 143/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6430 - val_loss: 0.6759
# Epoch 144/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6421 - val_loss: 0.6752
# Epoch 145/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6413 - val_loss: 0.6749
# Epoch 146/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6405 - val_loss: 0.6745
# Epoch 147/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6397 - val_loss: 0.6739
# Epoch 148/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6388 - val_loss: 0.6734
# Epoch 149/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6379 - val_loss: 0.6730
# Epoch 150/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6370 - val_loss: 0.6726
# Epoch 151/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6361 - val_loss: 0.6720
# Epoch 152/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6353 - val_loss: 0.6716
# Epoch 153/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6344 - val_loss: 0.6713
# Epoch 154/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6335 - val_loss: 0.6705
# Epoch 155/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6326 - val_loss: 0.6703
# Epoch 156/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6316 - val_loss: 0.6696
# Epoch 157/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6308 - val_loss: 0.6691
# Epoch 158/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6299 - val_loss: 0.6688
# Epoch 159/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6289 - val_loss: 0.6685
# Epoch 160/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6278 - val_loss: 0.6679
# Epoch 161/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6270 - val_loss: 0.6669
# Epoch 162/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6262 - val_loss: 0.6666
# Epoch 163/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6252 - val_loss: 0.6665
# Epoch 164/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6242 - val_loss: 0.6658
# Epoch 165/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6233 - val_loss: 0.6653
# Epoch 166/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6223 - val_loss: 0.6647
# Epoch 167/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6214 - val_loss: 0.6641
# Epoch 168/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6204 - val_loss: 0.6638
# Epoch 169/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6194 - val_loss: 0.6635
# Epoch 170/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6185 - val_loss: 0.6626
# Epoch 171/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6176 - val_loss: 0.6618
# Epoch 172/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6165 - val_loss: 0.6615
# Epoch 173/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6157 - val_loss: 0.6609
# Epoch 174/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6145 - val_loss: 0.6608
# Epoch 175/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6135 - val_loss: 0.6599
# Epoch 176/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6125 - val_loss: 0.6597
# Epoch 177/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6116 - val_loss: 0.6588
# Epoch 178/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6106 - val_loss: 0.6580
# Epoch 179/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6096 - val_loss: 0.6577
# Epoch 180/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6086 - val_loss: 0.6568
# Epoch 181/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6078 - val_loss: 0.6568
# Epoch 182/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6067 - val_loss: 0.6562
# Epoch 183/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.6057 - val_loss: 0.6550
# Epoch 184/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6046 - val_loss: 0.6548
# Epoch 185/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6037 - val_loss: 0.6547
# Epoch 186/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6026 - val_loss: 0.6538
# Epoch 187/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6016 - val_loss: 0.6534
# Epoch 188/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.6005 - val_loss: 0.6525
# Epoch 189/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5997 - val_loss: 0.6520
# Epoch 190/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5985 - val_loss: 0.6516
# Epoch 191/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5975 - val_loss: 0.6506
# Epoch 192/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5967 - val_loss: 0.6501
# Epoch 193/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5955 - val_loss: 0.6500
# Epoch 194/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5944 - val_loss: 0.6487
# Epoch 195/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5933 - val_loss: 0.6484
# Epoch 196/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5923 - val_loss: 0.6479
# Epoch 197/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5914 - val_loss: 0.6469
# Epoch 198/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5904 - val_loss: 0.6467
# Epoch 199/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5892 - val_loss: 0.6461
# Epoch 200/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5884 - val_loss: 0.6451
# Epoch 201/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5873 - val_loss: 0.6447
# Epoch 202/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5864 - val_loss: 0.6439
# Epoch 203/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5850 - val_loss: 0.6440
# Epoch 204/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5842 - val_loss: 0.6434
# Epoch 205/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5831 - val_loss: 0.6424
# Epoch 206/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5821 - val_loss: 0.6416
# Epoch 207/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5810 - val_loss: 0.6417
# Epoch 208/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5800 - val_loss: 0.6404
# Epoch 209/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5790 - val_loss: 0.6396
# Epoch 210/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5779 - val_loss: 0.6394
# Epoch 211/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5768 - val_loss: 0.6389
# Epoch 212/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5758 - val_loss: 0.6380
# Epoch 213/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5748 - val_loss: 0.6375
# Epoch 214/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5740 - val_loss: 0.6379
# Epoch 215/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5728 - val_loss: 0.6358
# Epoch 216/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5715 - val_loss: 0.6357
# Epoch 217/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5708 - val_loss: 0.6360
# Epoch 218/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5699 - val_loss: 0.6345
# Epoch 219/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5686 - val_loss: 0.6337
# Epoch 220/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5674 - val_loss: 0.6335
# Epoch 221/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5667 - val_loss: 0.6326
# Epoch 222/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5656 - val_loss: 0.6319
# Epoch 223/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5646 - val_loss: 0.6314
# Epoch 224/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5636 - val_loss: 0.6299
# Epoch 225/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5625 - val_loss: 0.6303
# Epoch 226/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5615 - val_loss: 0.6300
# Epoch 227/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5604 - val_loss: 0.6289
# Epoch 228/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5594 - val_loss: 0.6284
# Epoch 229/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5584 - val_loss: 0.6282
# Epoch 230/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5573 - val_loss: 0.6269
# Epoch 231/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5567 - val_loss: 0.6261
# Epoch 232/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5554 - val_loss: 0.6257
# Epoch 233/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5542 - val_loss: 0.6251
# Epoch 234/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5530 - val_loss: 0.6247
# Epoch 235/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5525 - val_loss: 0.6238
# Epoch 236/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5512 - val_loss: 0.6237
# Epoch 237/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5504 - val_loss: 0.6230
# Epoch 238/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5491 - val_loss: 0.6225
# Epoch 239/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5480 - val_loss: 0.6216
# Epoch 240/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5472 - val_loss: 0.6210
# Epoch 241/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5463 - val_loss: 0.6207
# Epoch 242/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5450 - val_loss: 0.6195
# Epoch 243/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5445 - val_loss: 0.6196
# Epoch 244/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5431 - val_loss: 0.6180
# Epoch 245/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5424 - val_loss: 0.6188
# Epoch 246/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5411 - val_loss: 0.6163
# Epoch 247/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5401 - val_loss: 0.6166
# Epoch 248/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5391 - val_loss: 0.6154
# Epoch 249/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5381 - val_loss: 0.6152
# Epoch 250/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5375 - val_loss: 0.6153
# Epoch 251/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5363 - val_loss: 0.6151
# Epoch 252/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5352 - val_loss: 0.6133
# Epoch 253/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5343 - val_loss: 0.6137
# Epoch 254/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5332 - val_loss: 0.6121
# Epoch 255/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5324 - val_loss: 0.6110
# Epoch 256/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5316 - val_loss: 0.6117
# Epoch 257/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5300 - val_loss: 0.6109
# Epoch 258/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5292 - val_loss: 0.6090
# Epoch 259/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5282 - val_loss: 0.6088
# Epoch 260/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5276 - val_loss: 0.6083
# Epoch 261/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5265 - val_loss: 0.6082
# Epoch 262/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5257 - val_loss: 0.6087
# Epoch 263/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5247 - val_loss: 0.6074
# Epoch 264/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5237 - val_loss: 0.6072
# Epoch 265/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5230 - val_loss: 0.6062
# Epoch 266/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5218 - val_loss: 0.6045
# Epoch 267/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5209 - val_loss: 0.6043
# Epoch 268/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5201 - val_loss: 0.6047
# Epoch 269/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5189 - val_loss: 0.6032
# Epoch 270/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5181 - val_loss: 0.6027
# Epoch 271/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5173 - val_loss: 0.6026
# Epoch 272/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5166 - val_loss: 0.6010
# Epoch 273/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5154 - val_loss: 0.6009
# Epoch 274/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5141 - val_loss: 0.6004
# Epoch 275/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5138 - val_loss: 0.6004
# Epoch 276/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5126 - val_loss: 0.5992
# Epoch 277/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5116 - val_loss: 0.5989
# Epoch 278/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5109 - val_loss: 0.5989
# Epoch 279/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5101 - val_loss: 0.5985
# Epoch 280/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5090 - val_loss: 0.5970
# Epoch 281/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5084 - val_loss: 0.5965
# Epoch 282/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5071 - val_loss: 0.5958
# Epoch 283/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5059 - val_loss: 0.5968
# Epoch 284/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5058 - val_loss: 0.5945
# Epoch 285/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5047 - val_loss: 0.5949
# Epoch 286/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5036 - val_loss: 0.5930
# Epoch 287/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5031 - val_loss: 0.5928
# Epoch 288/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5023 - val_loss: 0.5931
# Epoch 289/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.5010 - val_loss: 0.5916
# Epoch 290/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.5002 - val_loss: 0.5917
# Epoch 291/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.4994 - val_loss: 0.5901
# Epoch 292/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.4986 - val_loss: 0.5898
# Epoch 293/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4980 - val_loss: 0.5906
# Epoch 294/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.4971 - val_loss: 0.5887
# Epoch 295/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.4960 - val_loss: 0.5878
# Epoch 296/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4951 - val_loss: 0.5883
# Epoch 297/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4943 - val_loss: 0.5883
# Epoch 298/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4933 - val_loss: 0.5870
# Epoch 299/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4930 - val_loss: 0.5860
# Epoch 300/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4920 - val_loss: 0.5858
# Epoch 301/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4909 - val_loss: 0.5861
# Epoch 302/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4901 - val_loss: 0.5853
# Epoch 303/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4893 - val_loss: 0.5834
# Epoch 304/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4888 - val_loss: 0.5840
# Epoch 305/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.4879 - val_loss: 0.5836
# Epoch 306/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 0.4869 - val_loss: 0.5841
# 19/19 [==============================] - 3s 14ms/step
# (9496, 5856)
# Precision = 0.0234, HR = 0.1246, MRR = 0.0488, NDCG = 0.0664
# Fit [376.2 s]: Precision = 0.0234, HR = 0.1246, MRR = 0.0488, NDCG = 0.0664

# %%
# !nvidia-smi
# Out:
# Wed Jul 31 11:31:00 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.57       Driver Version: 515.57       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:47:00.0 Off |                  N/A |
# |  0%   48C    P2   106W / 350W |  22999MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import requests
headers = {"Authorization": "eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjQwMTY2LCJ1dWlkIjoiNmE1MGYzN2ItNTE1My00ZGY4LTkzZjYtZTJkNGRkZjhhMWM1IiwiaXNfYWRtaW4iOmZhbHNlLCJpc19zdXBlcl9hZG1pbiI6ZmFsc2UsInN1Yl9uYW1lIjoiIiwidGVuYW50IjoiYXV0b2RsIiwidXBrIjoiIn0.W9vekL_TuPpETo5tcNnSNn4lRLPj8znhZ7T4yFxDaKmpJIY4kLNN-RqKPHw0wZtYTZDoVE-QMlSW3Gem7Wi6Ww"}
resp = requests.post("https://www.autodl.com/api/v1/wechat/message/send",
                     json={
                         "title": "来自我的程序",
                         "name": "lgcn",
                         "content": 'hello'
                     }, headers = headers)
print(resp.content.decode())
# Out:
# {"code":"Success","data":null,"msg":""}
